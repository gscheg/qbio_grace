# %% [markdown]
# # Introduction to CPTAC
# This tutorial will introduce you to the CPTAC dataset through a (new) Python package called `cptac` that was written to access the CPTAC data. This package is similar to `TCGAbiolinks`. The package `cptac` is written using `pandas` dataframes. These dataframes are great and similar to some of the dataframes we navigated in R. This tutorial will introduce you to some of the uses of `pandas`. There is also a `pandas` cheat sheet in the Shared Folder that we recommend saving for future reference.
#
# `cptac` documentation: https://pypi.org/project/cptac/

# %% [markdown]
# ### Installing and Importing `cptac`
# Just as in R, we need to install before we can load in `cptac` to our current python environment. This installation only needs to occur once. In your terminal, install `cptac` into your conda environment. Double check that your conda environment is activated. At the very start of the line in the terminal, `(base)` means no conda environment is active. `(name_of_environment)` tells which conda environment you have activated.
#
# Install `cptac` with `pip install cptac`. Return to this notebook and run `import cptac`. If you are having trouble, try to close and restart the notebook.

# %% [markdown]
# ### Start exploring CPTAC with `cptac` (!!)
# Similar to `TCGAbiolinks`, we need to access and download the data. Take note of this syntax as you will need it for future reference.

# %%
import cptac
cptac.list_datasets()
# Out:
#                                            Description     Data reuse status  \
# Dataset name
# Brca                                     breast cancer       no restrictions
# Ccrcc         clear cell renal cell carcinoma (kidney)       no restrictions
# Colon                                colorectal cancer       no restrictions
# Endometrial            endometrial carcinoma (uterine)       no restrictions
# Gbm                                       glioblastoma       no restrictions
# Hnscc            head and neck squamous cell carcinoma       no restrictions
# Lscc                      lung squamous cell carcinoma  password access only
# Luad                               lung adenocarcinoma       no restrictions
# Ovarian               high grade serous ovarian cancer       no restrictions
# Pdac                  pancreatic ductal adenocarcinoma  password access only
#
#                                        Publication link
# Dataset name
# Brca          https://pubmed.ncbi.nlm.nih.gov/33212010/
# Ccrcc         https://pubmed.ncbi.nlm.nih.gov/31675502/
# Colon         https://pubmed.ncbi.nlm.nih.gov/31031003/
# Endometrial   https://pubmed.ncbi.nlm.nih.gov/32059776/
# Gbm           https://pubmed.ncbi.nlm.nih.gov/33577785/
# Hnscc         https://pubmed.ncbi.nlm.nih.gov/33417831/
# Lscc                                        unpublished
# Luad          https://pubmed.ncbi.nlm.nih.gov/32649874/
# Ovarian       https://pubmed.ncbi.nlm.nih.gov/27372738/
# Pdac                                        unpublished

# %%
cptac.download(dataset="Brca")
br = cptac.Brca()

# %% [markdown]
# The following lists the data available for the breast cancer dataset. Notice that even though this is through cptac (proteomics), we can also accesss the accompanying transcriptomics, CNV, etc. Additionally, we will be focusing on the proteomics, but acetylproteomics and phosphoproteomics are also interesting aspects to explore. They encompass "post-translational modifications". That is the addition of acetyl or phosphate groups to proteins after they are translated. This can often give insight into which proteins are being used in which cellular pathways.

# %%
br.list_data()
# Out:
# Below are the dataframes contained in this dataset:
# 	acetylproteomics
# 		Dimensions: (122, 9868)
# 	clinical
# 		Dimensions: (122, 23)
# 	CNV
# 		Dimensions: (122, 23692)
# 	derived_molecular
# 		Dimensions: (122, 32)
# 	followup
# 		Dimensions: (276, 95)
# 	phosphoproteomics
# 		Dimensions: (122, 38775)
# 	proteomics
# 		Dimensions: (122, 10107)
# 	somatic_mutation
# 		Dimensions: (24106, 3)
# 	transcriptomics
# 		Dimensions: (122, 23121)

# %%
protein_data = br.get_proteomics()

#The dataframes are MultIndex pandas dataframes. 
#However, to teach the basics of pandas, we will remove the "multi" part of the dataframe.
protein_data = protein_data.droplevel(1, axis=1)

protein_data
# Out:
# Name          A1BG     A2M   A2ML1    AAAS    AACS   AADAT   AAED1   AAGAB  \
# Patient_ID
# CPT000814  -0.6712 -0.2075  2.7959  1.3969 -1.0899     NaN  1.6708 -0.3484
# CPT001846   1.3964  1.3302 -5.0948  0.7674 -1.6845     NaN  2.1022 -0.5814
# X01BR001    2.0219  1.6269 -3.2943  0.3352 -1.0739  1.2255  0.2754 -1.1187
# X01BR008   -0.5290  0.3267  1.4342  0.4938 -2.8676     NaN     NaN -1.0691
# X01BR009    1.2556  3.4489  2.8043 -0.2956 -1.7261     NaN     NaN -2.0471
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# X21BR001   -0.6610 -0.6402 -4.8578  1.2319 -1.6491     NaN     NaN -0.3074
# X21BR002   -1.3735  0.4227 -4.9553  0.6327 -3.1434     NaN     NaN  0.3071
# X21BR010    1.1583  0.3329 -5.7358 -0.1658 -2.0413 -1.2433  0.9090 -0.2410
# X22BR005    0.4948 -1.0986 -8.8314  0.2826 -1.0123 -2.5732  5.7567  1.7644
# X22BR006    0.5049 -0.6582 -7.4699  0.6570 -0.7239     NaN  0.6420  2.2376
#
# Name          AAK1   AAMDC  ...  ZSCAN31  ZSWIM8    ZW10  ZWILCH   ZWINT  \
# Patient_ID                  ...
# CPT000814  -0.4756 -0.7299  ...  -5.2868 -0.6536  0.3384  2.1169  1.3910
# CPT001846   0.2916 -2.2857  ...  -0.7592  0.4711  0.6018  0.2062 -0.2137
# X01BR001   -0.0534 -0.2519  ...      NaN  0.2306 -0.3010  0.3395 -0.5316
# X01BR008   -0.3643 -1.8173  ...  -2.1789  0.2695  0.1506  1.0498  0.7546
# X01BR009   -0.3547 -0.8298  ...  -2.3990 -0.2596  0.1898 -0.5010 -0.4189
# ...            ...     ...  ...      ...     ...     ...     ...     ...
# X21BR001   -0.3074 -0.0266  ...  -0.2528  0.5090  0.0306  0.4908 -0.5570
# X21BR002    0.7562 -1.6912  ...  -3.3351  0.1548  1.0792 -0.6619 -1.4444
# X21BR010    0.6717 -0.1651  ...  -0.7054  0.2752  0.8850 -2.6704 -0.9444
# X22BR005    0.5415  0.1531  ...  -0.3936 -0.0340 -0.9367 -0.1922  1.2572
# X22BR006   -0.7597  0.1589  ...   0.5526  0.3468  1.0655 -1.2607 -2.2866
#
# Name          ZXDC  ZYG11B     ZYX   ZZEF1    ZZZ3
# Patient_ID
# CPT000814  -2.1230  0.9136 -0.8082 -1.4793  0.9136
# CPT001846  -2.1219  0.0860  2.5814 -0.2852 -0.1074
# X01BR001       NaN  0.4996  0.7622 -1.5607  0.0256
# X01BR008    1.7889 -0.2499 -0.2590 -0.1263  0.3725
# X01BR009    0.3080  0.5057  0.2181 -0.2288 -0.2750
# ...            ...     ...     ...     ...     ...
# X21BR001    2.3864  0.3764 -0.6974  1.3541  1.1123
# X21BR002   -0.3704  0.4909  0.3938  0.2992 -0.3494
# X21BR010   -1.9717  0.0650  0.6300 -0.0686  0.1798
# X22BR005    1.3220 -1.0698  0.4012 -0.3792  1.2752
# X22BR006    1.0775 -0.1334  2.5269  1.4294  0.4542
#
# [122 rows x 10107 columns]

# %% [markdown]
# ### Introduction to Pandas
# The following commands are basics to navigate through pandas dataframes. First we import pandas as a comman alias, `pd`. Remember there are additional python and pandas resources in the Shared Folder

# %%
import pandas as pd

# %%
#Juptyer gives a nice format for viewing pandas dataframes
protein_data
# Out:
# Name          A1BG     A2M   A2ML1    AAAS    AACS   AADAT   AAED1   AAGAB  \
# Patient_ID
# CPT000814  -0.6712 -0.2075  2.7959  1.3969 -1.0899     NaN  1.6708 -0.3484
# CPT001846   1.3964  1.3302 -5.0948  0.7674 -1.6845     NaN  2.1022 -0.5814
# X01BR001    2.0219  1.6269 -3.2943  0.3352 -1.0739  1.2255  0.2754 -1.1187
# X01BR008   -0.5290  0.3267  1.4342  0.4938 -2.8676     NaN     NaN -1.0691
# X01BR009    1.2556  3.4489  2.8043 -0.2956 -1.7261     NaN     NaN -2.0471
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# X21BR001   -0.6610 -0.6402 -4.8578  1.2319 -1.6491     NaN     NaN -0.3074
# X21BR002   -1.3735  0.4227 -4.9553  0.6327 -3.1434     NaN     NaN  0.3071
# X21BR010    1.1583  0.3329 -5.7358 -0.1658 -2.0413 -1.2433  0.9090 -0.2410
# X22BR005    0.4948 -1.0986 -8.8314  0.2826 -1.0123 -2.5732  5.7567  1.7644
# X22BR006    0.5049 -0.6582 -7.4699  0.6570 -0.7239     NaN  0.6420  2.2376
#
# Name          AAK1   AAMDC  ...  ZSCAN31  ZSWIM8    ZW10  ZWILCH   ZWINT  \
# Patient_ID                  ...
# CPT000814  -0.4756 -0.7299  ...  -5.2868 -0.6536  0.3384  2.1169  1.3910
# CPT001846   0.2916 -2.2857  ...  -0.7592  0.4711  0.6018  0.2062 -0.2137
# X01BR001   -0.0534 -0.2519  ...      NaN  0.2306 -0.3010  0.3395 -0.5316
# X01BR008   -0.3643 -1.8173  ...  -2.1789  0.2695  0.1506  1.0498  0.7546
# X01BR009   -0.3547 -0.8298  ...  -2.3990 -0.2596  0.1898 -0.5010 -0.4189
# ...            ...     ...  ...      ...     ...     ...     ...     ...
# X21BR001   -0.3074 -0.0266  ...  -0.2528  0.5090  0.0306  0.4908 -0.5570
# X21BR002    0.7562 -1.6912  ...  -3.3351  0.1548  1.0792 -0.6619 -1.4444
# X21BR010    0.6717 -0.1651  ...  -0.7054  0.2752  0.8850 -2.6704 -0.9444
# X22BR005    0.5415  0.1531  ...  -0.3936 -0.0340 -0.9367 -0.1922  1.2572
# X22BR006   -0.7597  0.1589  ...   0.5526  0.3468  1.0655 -1.2607 -2.2866
#
# Name          ZXDC  ZYG11B     ZYX   ZZEF1    ZZZ3
# Patient_ID
# CPT000814  -2.1230  0.9136 -0.8082 -1.4793  0.9136
# CPT001846  -2.1219  0.0860  2.5814 -0.2852 -0.1074
# X01BR001       NaN  0.4996  0.7622 -1.5607  0.0256
# X01BR008    1.7889 -0.2499 -0.2590 -0.1263  0.3725
# X01BR009    0.3080  0.5057  0.2181 -0.2288 -0.2750
# ...            ...     ...     ...     ...     ...
# X21BR001    2.3864  0.3764 -0.6974  1.3541  1.1123
# X21BR002   -0.3704  0.4909  0.3938  0.2992 -0.3494
# X21BR010   -1.9717  0.0650  0.6300 -0.0686  0.1798
# X22BR005    1.3220 -1.0698  0.4012 -0.3792  1.2752
# X22BR006    1.0775 -0.1334  2.5269  1.4294  0.4542
#
# [122 rows x 10107 columns]

# %% [markdown]
# ### Indexing into a pandas dataframe
# Pandas dataframe has rows and columns that are called "indices" and "columns" respectively.

# %%
protein_data.index
# Out:
# Index(['CPT000814', 'CPT001846', 'X01BR001', 'X01BR008', 'X01BR009',
#        'X01BR010', 'X01BR015', 'X01BR017', 'X01BR018', 'X01BR020',
#        ...
#        'X20BR002', 'X20BR005', 'X20BR006', 'X20BR007', 'X20BR008', 'X21BR001',
#        'X21BR002', 'X21BR010', 'X22BR005', 'X22BR006'],
#       dtype='object', name='Patient_ID', length=122)

# %%
#Print out the columns of protein_data, using .columns
protein_data.columns
# Out:
# Index(['A1BG', 'A2M', 'A2ML1', 'AAAS', 'AACS', 'AADAT', 'AAED1', 'AAGAB',
#        'AAK1', 'AAMDC',
#        ...
#        'ZSCAN31', 'ZSWIM8', 'ZW10', 'ZWILCH', 'ZWINT', 'ZXDC', 'ZYG11B', 'ZYX',
#        'ZZEF1', 'ZZZ3'],
#       dtype='object', name='Name', length=10107)

# %% [markdown]
# Q: What do the indices(rows) and columns of protein_data represent?
#
# A: The indices represent patient samples and the columns represent protein names.

# %%
#Use the len() function to answer the following. 
#How many patients are in this cptac dataset?
#How many genes are listed in protein_data?

#Hint: Is patients the index or columns? Use .index and .columns!
print(len(protein_data.index)) #122 patients are in this dataset
print(len(protein_data.columns)) #10107 genes are listed
# Out:
# 122
# 10107

# %%
#Use can also view the dimensions of a pandas dataframe via df.shape
#What are the dimensions of protein_data using .shape?
#Check your understanding: What does .shape print out? Consider the previous block of code

protein_data.shape #dimensions: 122 by 10107
#.shape prints out a tuple: the number of indices is the first element and the number of columns is the second
# Out:
# (122, 10107)

# %% [markdown]
# There are multiple ways to index into a dataframe that you will see below. The first is to access an entire column using `dataframe["name_of_column"]`

# %%
#Use this format to access all rows of the ESR1 column 
protein_data["ESR1"]
# Out:
# Patient_ID
# CPT000814   -3.4457
# CPT001846   -2.7440
# X01BR001    -3.4950
# X01BR008    -4.2108
# X01BR009    -2.9871
#               ...
# X21BR001     3.1223
# X21BR002     2.7256
# X21BR010     2.2810
# X22BR005    -0.6634
# X22BR006    -2.1793
# Name: ESR1, Length: 122, dtype: float64

# %% [markdown]
# Another way to index into pandas dataframes is using `.iloc` and `.loc`. `.iloc` uses the numerical indices of a row and column. For example the top left element of a dataframe (named df) would be accessed via `df.iloc[1,1]`. The `.loc` uses the name of a row and column. For example `df.loc["row_name", "col_name"]`.

# %%
#Use iloc to access the element at (23,54) in protein_data
protein_data.iloc[23,54]
# Out:
# 0.2273

# %%
#Use loc to access row="X01BR017" and column="ESR1" 
#How would you interpret this value?
protein_data.loc["X01BR017", "ESR1"]
#this is the ESR1 protein data for the patient with barcode X01BR017
# Out:
# -4.4009

# %%
#You can also access all columns of one row by using an :
protein_data.loc["CPT000814", :]
protein_data.iloc[0,:]
# Out:
# Name
# A1BG     -0.6712
# A2M      -0.2075
# A2ML1     2.7959
# AAAS      1.3969
# AACS     -1.0899
#            ...
# ZXDC     -2.1230
# ZYG11B    0.9136
# ZYX      -0.8082
# ZZEF1    -1.4793
# ZZZ3      0.9136
# Name: CPT000814, Length: 10107, dtype: float64

# %% [markdown]
# Q: Which type(s) of indexing into the pandas dataframe do you think will be most helpful in this project?
#
# A: The first method, dataframe["name_of_column"], and the last method, using : in the column index, will probably be most helpful, as we won't be too interested in individual pieces of data.  Accessing a single column will allow us to look at trends for a single protein across all patients.

# %% [markdown]
# ## Additional datatypes in cptac
# You can also access other datatypes using the `cptac` python package for the same patients.

# %%
rna_data = br.get_transcriptomics()
clinical_data = br.get_clinical()

# %%
#Notice: Does this look similar or different to the previous data we were working with?
#similar, just with more columns
rna_data
# Out:
# Name          A1BG  A1BG-AS1  A1CF     A2M   A2ML1   A2MP1  A3GALT2  A4GALT  \
# Patient_ID
# CPT000814  -0.2020    0.4851   NaN -1.0264  5.3754 -1.7357  -2.6428 -1.0939
# CPT001846   1.5602    0.8676   NaN -1.1659 -2.3353  1.7850   7.8635  1.3619
# X01BR001   -0.4547    1.7415   NaN -0.3769  2.1803  1.3121      NaN  0.8310
# X01BR008   -1.4653    0.4251   NaN -0.5979  5.8009  0.5635  -2.6931 -1.0861
# X01BR009    1.0341    2.0925   NaN  0.6195  7.0649 -0.7143      NaN  0.2492
# ...            ...       ...   ...     ...     ...     ...      ...     ...
# X21BR001   -0.0196    0.2171   NaN -0.3940 -2.0997  1.0183   6.4045 -0.2501
# X21BR002       NaN       NaN   NaN  2.1073 -4.0915     NaN      NaN  3.8259
# X21BR010   -3.2675   -1.0806   NaN  0.4900     NaN -0.1154      NaN -5.5735
# X22BR005   -4.2705   -1.4557   NaN  0.3112  1.8311  1.1163      NaN  0.6396
# X22BR006   -2.4837   -0.2383   NaN  1.4869 -2.5440     NaN      NaN -0.1171
#
# Name         A4GNT    AAAS  ...  ZWILCH   ZWINT    ZXDA    ZXDB    ZXDC  \
# Patient_ID                  ...
# CPT000814      NaN  0.2623  ...  0.2799  0.5755 -0.5886 -0.7428  1.5763
# CPT001846      NaN -0.0019  ...  0.4305 -0.4707 -2.0699 -2.0325 -0.0221
# X01BR001       NaN -0.3131  ... -0.2010 -1.6472  0.3005  0.3112  0.3747
# X01BR008       NaN  0.0043  ...  0.3331  1.3433 -1.8711 -1.3578  0.0305
# X01BR009   -2.2484  0.4772  ... -0.0054 -1.0478 -1.3751 -1.8079 -0.1200
# ...            ...     ...  ...     ...     ...     ...     ...     ...
# X21BR001   -1.7260  0.6178  ... -0.7115  0.1819 -1.2171 -1.3631  1.3455
# X21BR002       NaN  0.6250  ... -0.7193 -0.3678 -1.8014 -1.4538  1.5637
# X21BR010       NaN -1.2094  ... -0.6299 -3.1189  0.7028  0.7773 -0.1069
# X22BR005       NaN  0.0104  ... -0.0333  1.2037 -0.0319  0.2372 -0.9557
# X22BR006       NaN  0.8315  ... -0.9753 -2.5921  1.1066  0.8053 -1.1356
#
# Name        ZYG11A  ZYG11B     ZYX   ZZEF1    ZZZ3
# Patient_ID
# CPT000814   2.3063 -0.9448  0.6603  0.2159  0.1554
# CPT001846      NaN  0.0745  1.9567 -0.4364 -0.1601
# X01BR001    1.0260  0.2738 -0.0211  0.3720 -0.6570
# X01BR008    1.3676 -1.6430  0.3679  0.6431 -0.1793
# X01BR009   -4.6279 -0.8619 -0.0338  1.5769 -0.6337
# ...            ...     ...     ...     ...     ...
# X21BR001       NaN -0.7515  0.3044  1.3806 -1.1197
# X21BR002       NaN -0.5786  0.8320  1.0435 -1.1151
# X21BR010   -4.5936  0.9043 -1.5439 -1.4296  0.9932
# X22BR005    0.5448 -0.4072 -1.2626 -0.9846  1.2978
# X22BR006   -0.2454  2.0016  2.2719  1.3618 -0.2480
#
# [122 rows x 23121 columns]

# %%
clinical_data
# Out:
# Name       Replicate_Measurement_IDs Sample_Tumor_Normal  Age.in.Month  \
# Patient_ID
# CPT000814                  CPT000814               Tumor           NaN
# CPT001846                  CPT001846               Tumor           NaN
# X01BR001                    X01BR001               Tumor         660.0
# X01BR008                    X01BR008               Tumor           NaN
# X01BR009                    X01BR009               Tumor           NaN
# ...                              ...                 ...           ...
# X21BR001                    X21BR001               Tumor           NaN
# X21BR002                    X21BR002               Tumor           NaN
# X21BR010      X21BR010|X21BR010.REP1               Tumor         852.0
# X22BR005                    X22BR005               Tumor         552.0
# X22BR006                    X22BR006               Tumor         660.0
#
# Name        Gender                       Race Human.Readable.Label Experiment  \
# Patient_ID
# CPT000814      NaN  black.or.african.american       CPT000814 0004         13
# CPT001846      NaN                      white       CPT001846 0005         12
# X01BR001    female  black.or.african.american       [17]-af938b_D2          2
# X01BR008       NaN                        NaN       [cf]-467c39_D1         16
# X01BR009       NaN                        NaN       [0e]-051582_D1         16
# ...            ...                        ...                  ...        ...
# X21BR001       NaN                      white          [1f]-d9108c         16
# X21BR002       NaN                      white          [32]-22665e         16
# X21BR010    female                      white       [68]-4d3e43_D2       3|17
# X22BR005    female                      white       [12]-1af490_D2          6
# X22BR006    female  black.or.african.american       [a2]-5d5f11_D2         10
#
# Name          Channel       Stage  PAM50  ... ER.IHC.Score PR.IHC.Score  \
# Patient_ID                                ...
# CPT000814        127C   Stage IIA  Basal  ...          NaN          NaN
# CPT001846        128C   Stage III  Basal  ...          NaN          NaN
# X01BR001         129N   Stage IIB  Basal  ...            0            0
# X01BR008         127C         NaN  Basal  ...          NaN          NaN
# X01BR009         127N         NaN  Basal  ...          NaN          NaN
# ...               ...         ...    ...  ...          ...          ...
# X21BR001         128N         NaN   LumB  ...          NaN          NaN
# X21BR002         128C         NaN   LumA  ...          NaN          NaN
# X21BR010    129C|128C   Stage IIA   LumA  ...           3+           3+
# X22BR005         129N   Stage IIB   LumA  ...           3+           3+
# X22BR006         130N  Stage IIIA   LumA  ...           2+           3+
#
# Name       Coring.or.Excision Ischemia.Time.in.Minutes Ischemia.Decade  \
# Patient_ID
# CPT000814                 NaN                      NaN             NaN
# CPT001846                 NaN                      NaN             NaN
# X01BR001               coring                      0.0             1.0
# X01BR008                  NaN                      NaN             NaN
# X01BR009                  NaN                      NaN             NaN
# ...                       ...                      ...             ...
# X21BR001                  NaN                      NaN             NaN
# X21BR002                  NaN                      NaN             NaN
# X21BR010             excision                     18.0             2.0
# X22BR005             excision                     20.0             2.0
# X22BR006             excision                     25.0             3.0
#
# Name       Necrosis  Tumor.Cellularity  Total.Cellularity  In.CR  QC.status
# Patient_ID
# CPT000814       NaN                NaN                NaN    NaN    QC.pass
# CPT001846       NaN                NaN                NaN    NaN    QC.pass
# X01BR001       10.0               70.0               50.0    yes    QC.pass
# X01BR008        0.0               90.0               60.0     no    QC.pass
# X01BR009        0.0               80.0               70.0     no    QC.pass
# ...             ...                ...                ...    ...        ...
# X21BR001        0.0               60.0               80.0     no    QC.pass
# X21BR002        0.0               65.0               60.0     no    QC.pass
# X21BR010        0.0               60.0               55.0    yes    QC.pass
# X22BR005       15.0               65.0               75.0     no    QC.pass
# X22BR006        NaN                NaN                NaN     no    QC.pass
#
# [122 rows x 23 columns]

# %%
#Use your knowledge of the unique() function from the first tutorial 
#What do you need to import?
#Now use the unique function on the PAM50 column of clinical data
import numpy
numpy.unique(clinical_data["PAM50"])
# Out:
# array(['Basal', 'Her2', 'LumA', 'LumB', 'Normal'], dtype=object)

# %%
#What is the race distribution of the 122 patients?
numpy.unique(clinical_data["Race"].astype(str), return_counts = True)
#19 Asian, 14 black, 4 Hispanic/latino, 78 white
# Out:
# (array(['Not reported', 'asian', 'black.or.african.american',
#         'hispanic.or.latino', 'white'], dtype=object),
#  array([ 7, 19, 14,  4, 78]))

# %%
#What if we are interested in race and subtype distribution?
#Follow the steps to find the percent of each subtype in each race

#Notice that there are some NaN's in the Race column. 
#The .fillna() allows us to replace all NaN's with "Not reported"
clinical_data["Race"] = clinical_data["Race"].fillna("Not reported")

#Use the unique() function to find the different races
race_list = list(numpy.unique(clinical_data["Race"].astype(str)))
    
#repeat for the PAM50 column
pam50_list = list(numpy.unique(clinical_data["PAM50"]))

#We will append the total number of patients for each race
total_race = []*len(race_list)

#We will now use a NESTED FOR LOOP
for race in race_list:
    #print race for clarity 
    print(race)
    #PAUSE and make sure you understand these line. We are back to boolean indexing!
    race_boolean_mask = clinical_data["Race"] == race 
    pam50_column_of_race = clinical_data["PAM50"][ race_boolean_mask ]
    
    #fill in the (). Think about how to get the number of patients of a certain race
    total_race.append(sum(race_boolean_mask == True))
    
    for subtype in pam50_list:
        #print subtype for clarity
        print(subtype)
        #create a boolean_mask using the pam50_column_of_race that is True when it is equal to subtype and false otherwise
        pam50_race_mask = pam50_column_of_race == subtype
        num_pam50_and_race_patients = sum(pam50_race_mask)
        
        #Calculate the percent of patients in a race group with subtype
        #Create a print statement that prints out relevant information
        #Example: 30% of black.or.african.american patients are LumA
        patients_with_sub = num_pam50_and_race_patients/(total_race[len(total_race)-1])*100
        print(patients_with_sub, " % of ", race, " patients are ", subtype)
# Out:
# Not reported
# Basal
# 42.857142857142854  % of  Not reported  patients are  Basal
# Her2
# 14.285714285714285  % of  Not reported  patients are  Her2
# LumA
# 42.857142857142854  % of  Not reported  patients are  LumA
# LumB
# 0.0  % of  Not reported  patients are  LumB
# Normal
# 0.0  % of  Not reported  patients are  Normal
# asian
# Basal
# 10.526315789473683  % of  asian  patients are  Basal
# Her2
# 21.052631578947366  % of  asian  patients are  Her2
# LumA
# 42.10526315789473  % of  asian  patients are  LumA
# LumB
# 15.789473684210526  % of  asian  patients are  LumB
# Normal
# 10.526315789473683  % of  asian  patients are  Normal
# black.or.african.american
# Basal
# 57.14285714285714  % of  black.or.african.american  patients are  Basal
# Her2
# 7.142857142857142  % of  black.or.african.american  patients are  Her2
# LumA
# 35.714285714285715  % of  black.or.african.american  patients are  LumA
# LumB
# 0.0  % of  black.or.african.american  patients are  LumB
# Normal
# 0.0  % of  black.or.african.american  patients are  Normal
# hispanic.or.latino
# Basal
# 0.0  % of  hispanic.or.latino  patients are  Basal
# Her2
# 25.0  % of  hispanic.or.latino  patients are  Her2
# LumA
# 50.0  % of  hispanic.or.latino  patients are  LumA
# LumB
# 0.0  % of  hispanic.or.latino  patients are  LumB
# Normal
# 25.0  % of  hispanic.or.latino  patients are  Normal
# white
# Basal
# 20.51282051282051  % of  white  patients are  Basal
# Her2
# 8.974358974358974  % of  white  patients are  Her2
# LumA
# 50.0  % of  white  patients are  LumA
# LumB
# 17.94871794871795  % of  white  patients are  LumB
# Normal
# 2.564102564102564  % of  white  patients are  Normal

# %%
#We are interested in age, but notice that age is listed in months
#Create a new column in clinical_data that has age in years
clinical_data["Age_in_years"] = clinical_data["Age.in.Month"]/12 #fill in with correct math

# %%
#Pandas has handy min(), max(), mean(), median(), etc. 
print( clinical_data["Age_in_years"].min() )

#Try the other functions!
print(clinical_data["Age_in_years"].max())
print(clinical_data["Age_in_years"].mean())
print(clinical_data["Age_in_years"].median())
# Out:
# 30.916666666666668
# 95.33333333333333
# 60.63650793650794
# 61.5

# %%
#Get creative. Use what you've learned in Python to create a new column in clinical_data called Age_category
#For patients under 40, assign "Young", 41-59 "Mid", and 60+ is "Old"
#There are multiple ways to do this. You can use a for loop (they are pretty fast in python) or use boolean indexing!
#How many young, old, and mid patients are there?
clinical_data["Age_category"] = ["NA"]*len(clinical_data.index)

for i in range(len(clinical_data.index)):
    if clinical_data.iloc[i, clinical_data.columns.get_loc("Age_in_years")] <= 40:
        clinical_data.iloc[i, clinical_data.columns.get_loc("Age_category")] = "Young"
    elif clinical_data.iloc[i, clinical_data.columns.get_loc("Age_in_years")] >= 60:
        clinical_data.iloc[i, clinical_data.columns.get_loc("Age_category")] = "Old"
    else:
        clinical_data.iloc[i, clinical_data.columns.get_loc("Age_category")] = "Mid"
print(sum(clinical_data["Age_category"] == "Young"))
print(sum(clinical_data["Age_category"] == "Mid"))
print(sum(clinical_data["Age_category"] == "Old"))
#There are 9 young, 56 mid, and 57 old patients.
# Out:
# 9
# 56
# 57

# %%
#Repeat the above cell by creating a new column called Age_category_check
#However, use a different method in creating this column
#Run clinical_data["Age_category"] == clinical_data["Age_category_check"] to see if they are equal
old_bool_mask = clinical_data["Age_in_years"] >= 60
young_bool_mask = clinical_data["Age_in_years"] <= 40
mid_bool_mask = (clinical_data["Age_in_years"] != old_bool_mask) & (clinical_data["Age_in_years"] != young_bool_mask)
bool_masks = [old_bool_mask == True, young_bool_mask == True, mid_bool_mask == True]
assign_age = ["Old", "Young", "Mid"]
clinical_data["Age_category_check"] = numpy.select(bool_masks, assign_age)
    
print(sum(clinical_data["Age_category_check"] == "Young"))
print(sum(clinical_data["Age_category_check"] == "Mid"))
print(sum(clinical_data["Age_category_check"] == "Old"))
clinical_data["Age_category"] == clinical_data["Age_category_check"] #evaluates to true, so both columns are equal
# Out:
# 9
# 56
# 57
# Patient_ID
# CPT000814    True
# CPT001846    True
# X01BR001     True
# X01BR008     True
# X01BR009     True
#              ...
# X21BR001     True
# X21BR002     True
# X21BR010     True
# X22BR005     True
# X22BR006     True
# Length: 122, dtype: bool

# %% [markdown]
# ## Plotting in Python
# There are two primary libraries that are used to plot in Python: `matplotlib` and `seaborn`. `seaborn` is built ontop of `matplotlib` so they are very similar.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#We might want to compare the transcriptomics and proteomics of the same gene
#Check for understanding: Why might this be of interest? What is the expected the relationship between the two?
#This relates to the central dogma: DNA --> RNA --> protein.  It might be interesting to see what changes exist 
#between RNA expression and protein abundance for the same gene, because we'd expect the two to correlate.

#Pick your favorite gene and assign it to the gene variable
gene = "TP53"

#assert statements are important for ensuring your code is running correctly
#The program will only continue running if the statement after assert is True
assert gene in rna_data.columns
assert gene in protein_data.columns

#We also want to check that the patients are in the same order for rna_data and protein_data.
#Write an assert statement that checks this. Fill in parathensis
assert list(rna_data.index) == list(protein_data.index)

#for matplotlib we always have to create a figure before we plot! Can play around with the figure size
plt.figure( figsize=(10,10) )

#x axis will be the proteomics data of the particular gene. 
#Set x_data equal to the column of protein_data that corresponds to your gene
x_data = protein_data[gene]

#y axis will be the transcriptomics data of the particular gene. 
#Set x_data equal to the column of rna_data that corresponds to your gene
y_data = rna_data[gene]

#Use matplotlib's scatter() function to create a scatter plot. Is this what you expect
plt.scatter(x_data, y_data)

#Edit the figure
plt.title("RNA vs. protein data for TP53 gene")
plt.xlabel("protein abundance")
plt.ylabel("mRNA transcripts")

#This is used to explicitly print out the figure. Later we will save the figure
plt.show()

# %% [markdown]
# ### Saving pandas dataframes
# While you can certainly reload in the data every time you wish to use it, we also want to make sure you know how to save and read in a pandas dataframes. We will utilize the `to_csv()` function and `read_csv()` function. Notice in the `read_csv()` function we utilize the `index_col` argument. To observe what this argument does, try removing it and looking at the dataframe. Notice what the index values are.

# %%
#You can just put a filename.csv if you would like the file to be saved in the current folder
protein_data.to_csv("protein_data.csv")
protein_data_read_example = pd.read_csv("protein_data.csv", index_col=0)
protein_data_read_example
# Out:
#               A1BG     A2M   A2ML1    AAAS    AACS   AADAT   AAED1   AAGAB  \
# Patient_ID
# CPT000814  -0.6712 -0.2075  2.7959  1.3969 -1.0899     NaN  1.6708 -0.3484
# CPT001846   1.3964  1.3302 -5.0948  0.7674 -1.6845     NaN  2.1022 -0.5814
# X01BR001    2.0219  1.6269 -3.2943  0.3352 -1.0739  1.2255  0.2754 -1.1187
# X01BR008   -0.5290  0.3267  1.4342  0.4938 -2.8676     NaN     NaN -1.0691
# X01BR009    1.2556  3.4489  2.8043 -0.2956 -1.7261     NaN     NaN -2.0471
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# X21BR001   -0.6610 -0.6402 -4.8578  1.2319 -1.6491     NaN     NaN -0.3074
# X21BR002   -1.3735  0.4227 -4.9553  0.6327 -3.1434     NaN     NaN  0.3071
# X21BR010    1.1583  0.3329 -5.7358 -0.1658 -2.0413 -1.2433  0.9090 -0.2410
# X22BR005    0.4948 -1.0986 -8.8314  0.2826 -1.0123 -2.5732  5.7567  1.7644
# X22BR006    0.5049 -0.6582 -7.4699  0.6570 -0.7239     NaN  0.6420  2.2376
#
#               AAK1   AAMDC  ...  ZSCAN31  ZSWIM8    ZW10  ZWILCH   ZWINT  \
# Patient_ID                  ...
# CPT000814  -0.4756 -0.7299  ...  -5.2868 -0.6536  0.3384  2.1169  1.3910
# CPT001846   0.2916 -2.2857  ...  -0.7592  0.4711  0.6018  0.2062 -0.2137
# X01BR001   -0.0534 -0.2519  ...      NaN  0.2306 -0.3010  0.3395 -0.5316
# X01BR008   -0.3643 -1.8173  ...  -2.1789  0.2695  0.1506  1.0498  0.7546
# X01BR009   -0.3547 -0.8298  ...  -2.3990 -0.2596  0.1898 -0.5010 -0.4189
# ...            ...     ...  ...      ...     ...     ...     ...     ...
# X21BR001   -0.3074 -0.0266  ...  -0.2528  0.5090  0.0306  0.4908 -0.5570
# X21BR002    0.7562 -1.6912  ...  -3.3351  0.1548  1.0792 -0.6619 -1.4444
# X21BR010    0.6717 -0.1651  ...  -0.7054  0.2752  0.8850 -2.6704 -0.9444
# X22BR005    0.5415  0.1531  ...  -0.3936 -0.0340 -0.9367 -0.1922  1.2572
# X22BR006   -0.7597  0.1589  ...   0.5526  0.3468  1.0655 -1.2607 -2.2866
#
#               ZXDC  ZYG11B     ZYX   ZZEF1    ZZZ3
# Patient_ID
# CPT000814  -2.1230  0.9136 -0.8082 -1.4793  0.9136
# CPT001846  -2.1219  0.0860  2.5814 -0.2852 -0.1074
# X01BR001       NaN  0.4996  0.7622 -1.5607  0.0256
# X01BR008    1.7889 -0.2499 -0.2590 -0.1263  0.3725
# X01BR009    0.3080  0.5057  0.2181 -0.2288 -0.2750
# ...            ...     ...     ...     ...     ...
# X21BR001    2.3864  0.3764 -0.6974  1.3541  1.1123
# X21BR002   -0.3704  0.4909  0.3938  0.2992 -0.3494
# X21BR010   -1.9717  0.0650  0.6300 -0.0686  0.1798
# X22BR005    1.3220 -1.0698  0.4012 -0.3792  1.2752
# X22BR006    1.0775 -0.1334  2.5269  1.4294  0.4542
#
# [122 rows x 10107 columns]

# %%
#Save and read in the clinical_data file
clinical_data.to_csv("clinical_data.csv")
clinical_data_read_example = pd.read_csv("clinical_data.csv", index_col=0)
clinical_data_read_example
# Out:
#            Replicate_Measurement_IDs Sample_Tumor_Normal  Age.in.Month  \
# Patient_ID
# CPT000814                  CPT000814               Tumor           NaN
# CPT001846                  CPT001846               Tumor           NaN
# X01BR001                    X01BR001               Tumor         660.0
# X01BR008                    X01BR008               Tumor           NaN
# X01BR009                    X01BR009               Tumor           NaN
# ...                              ...                 ...           ...
# X21BR001                    X21BR001               Tumor           NaN
# X21BR002                    X21BR002               Tumor           NaN
# X21BR010      X21BR010|X21BR010.REP1               Tumor         852.0
# X22BR005                    X22BR005               Tumor         552.0
# X22BR006                    X22BR006               Tumor         660.0
#
#             Gender                       Race Human.Readable.Label Experiment  \
# Patient_ID
# CPT000814      NaN  black.or.african.american       CPT000814 0004         13
# CPT001846      NaN                      white       CPT001846 0005         12
# X01BR001    female  black.or.african.american       [17]-af938b_D2          2
# X01BR008       NaN               Not reported       [cf]-467c39_D1         16
# X01BR009       NaN               Not reported       [0e]-051582_D1         16
# ...            ...                        ...                  ...        ...
# X21BR001       NaN                      white          [1f]-d9108c         16
# X21BR002       NaN                      white          [32]-22665e         16
# X21BR010    female                      white       [68]-4d3e43_D2       3|17
# X22BR005    female                      white       [12]-1af490_D2          6
# X22BR006    female  black.or.african.american       [a2]-5d5f11_D2         10
#
#               Channel       Stage  PAM50  ... Coring.or.Excision  \
# Patient_ID                                ...
# CPT000814        127C   Stage IIA  Basal  ...                NaN
# CPT001846        128C   Stage III  Basal  ...                NaN
# X01BR001         129N   Stage IIB  Basal  ...             coring
# X01BR008         127C         NaN  Basal  ...                NaN
# X01BR009         127N         NaN  Basal  ...                NaN
# ...               ...         ...    ...  ...                ...
# X21BR001         128N         NaN   LumB  ...                NaN
# X21BR002         128C         NaN   LumA  ...                NaN
# X21BR010    129C|128C   Stage IIA   LumA  ...           excision
# X22BR005         129N   Stage IIB   LumA  ...           excision
# X22BR006         130N  Stage IIIA   LumA  ...           excision
#
#            Ischemia.Time.in.Minutes Ischemia.Decade Necrosis  \
# Patient_ID
# CPT000814                       NaN             NaN      NaN
# CPT001846                       NaN             NaN      NaN
# X01BR001                        0.0             1.0     10.0
# X01BR008                        NaN             NaN      0.0
# X01BR009                        NaN             NaN      0.0
# ...                             ...             ...      ...
# X21BR001                        NaN             NaN      0.0
# X21BR002                        NaN             NaN      0.0
# X21BR010                       18.0             2.0      0.0
# X22BR005                       20.0             2.0     15.0
# X22BR006                       25.0             3.0      NaN
#
#            Tumor.Cellularity Total.Cellularity  In.CR  QC.status  \
# Patient_ID
# CPT000814                NaN               NaN    NaN    QC.pass
# CPT001846                NaN               NaN    NaN    QC.pass
# X01BR001                70.0              50.0    yes    QC.pass
# X01BR008                90.0              60.0     no    QC.pass
# X01BR009                80.0              70.0     no    QC.pass
# ...                      ...               ...    ...        ...
# X21BR001                60.0              80.0     no    QC.pass
# X21BR002                65.0              60.0     no    QC.pass
# X21BR010                60.0              55.0    yes    QC.pass
# X22BR005                65.0              75.0     no    QC.pass
# X22BR006                 NaN               NaN     no    QC.pass
#
#             Age_category  Age_in_years
# Patient_ID
# CPT000814              0           NaN
# CPT001846              0           NaN
# X01BR001               0          55.0
# X01BR008               0           NaN
# X01BR009               0           NaN
# ...                  ...           ...
# X21BR001               0           NaN
# X21BR002               0           NaN
# X21BR010               0          71.0
# X22BR005               0          46.0
# X22BR006               0          55.0
#
# [122 rows x 25 columns]

# %% [markdown]
# ### This is the end of the tutorial we created. However, if you are interested there are more tutorials and use cases of `cptac` here: https://pypi.org/project/cptac/
